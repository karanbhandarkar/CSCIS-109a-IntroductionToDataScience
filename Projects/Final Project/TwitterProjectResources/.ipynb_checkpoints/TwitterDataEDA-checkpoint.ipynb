# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tweets_train_DF = pd.read_csv("data/training_data.csv")

# %%
tweets_train_DF.head()
# Out:
#              id                id_str       screen_name  \
# 0  8.160000e+17  "815745789754417152"  "HoustonPokeMap"
# 1  4.843621e+09            4843621225         kernyeahx
# 2  4.303727e+09            4303727112   mattlieberisbot
# 3  3.063139e+09            3063139353         sc_papers
# 4  2.955142e+09            2955142070      lucarivera16
#
#                     location  \
# 0              "Houston, TX"
# 1  Templeville town, MD, USA
# 2                        NaN
# 3                        NaN
# 4      Dublin, United States
#
#                                          description  \
# 0  "Rare and strong PokŽmon in Houston, TX. See m...
# 1  From late 2014 Socium Marketplace will make sh...
# 2  Inspired by the smart, funny folks at @replyal...
# 3                                                NaN
# 4             Inspiring cooks everywhere since 1956.
#
#                          url  followers_count  friends_count  listed_count  \
# ...

# %%
tweetsDF.head()
# Out:
#    contributors coordinates          created_at  \
# 0           NaN        None 2018-07-12 00:20:29
# 1           NaN        None 2018-07-12 00:20:28
# 2           NaN        None 2018-07-12 00:20:26
# 3           NaN        None 2018-07-12 00:20:23
# 4           NaN        None 2018-07-12 00:20:22
#
#                                             entities extended_entities  \
# 0  {'hashtags': [], 'symbols': [], 'urls': [], 'u...               NaN
# 1  {'hashtags': [], 'symbols': [], 'urls': [{'dis...               NaN
# 2  {'hashtags': [], 'symbols': [], 'urls': [], 'u...               NaN
# 3  {'hashtags': [], 'symbols': [], 'urls': [], 'u...               NaN
# 4  {'hashtags': [], 'symbols': [], 'urls': [], 'u...               NaN
#
#    favorite_count  favorited   geo                   id               id_str  \
# 0               0      False  None  1017201997601222657  1017201997601222656
# 1               0      False  None  1017201994719813633  1017201994719813632
# ...
