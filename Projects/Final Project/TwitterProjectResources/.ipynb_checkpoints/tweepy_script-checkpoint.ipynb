# %% [markdown]
# # Access the Twitter API using tweepy (see the provided "Twitter Dev Account Setup Instructions" for details on how to set up a free twitter dev account)

# %%
# http://www.tweepy.org/
import tweepy

# Replace the API_KEY and API_SECRET with your application's key and secret.
# auth = tweepy.AppAuthHandler("API_KEY", "API_SECRET")
auth = tweepy.AppAuthHandler("J2MIKx3BXACA5zK1bdM1uuZyy", "0HBek6qLr2PV1I5gDiUlZCu3EcYAmnvVMOrtYbqqKAl7ob7wg7")

api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
 
if (not api):
    print ("Can't Authenticate")
    sys.exit(-1)

# %% [markdown]
# # Run the tweepy script to save tweets that include the desired search query to a json file on disk.

# %%
import sys
import jsonpickle
import os

searchQuery = 'Harvard'  # this is what we're searching for
maxTweets = 100000 # some arbitrary large number
tweetsPerQry = 100  # this is the max the API permits
fName = 'tweets.json' # we'll store the tweets in a text file.

# If results from a specific ID onwards are reqd, set since_id to that ID.
# else default to no lower limit, go as far back as API allows
sinceId = None

# If results only below a specific ID are, set max_id to that ID.
# else default to no upper limit, start from the most recent tweet matching the search query.
max_id = -1

tweetCount = 0
print("Downloading max {0} tweets".format(maxTweets))
with open(fName, 'w') as f:
    while tweetCount < maxTweets:
        try:
            if (max_id <= 0):
                if (not sinceId):
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry)
                else:
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                            since_id=sinceId)
            else:
                if (not sinceId):
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                            max_id=str(max_id - 1))
                else:
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                            max_id=str(max_id - 1),
                                            since_id=sinceId)
            if not new_tweets:
                print("No more tweets found")
                break
            for tweet in new_tweets:
                f.write(jsonpickle.encode(tweet._json, unpicklable=False) +
                        '\n')
            tweetCount += len(new_tweets)
            print("Downloaded {0} tweets".format(tweetCount))
            max_id = new_tweets[-1].id
        except tweepy.TweepError as e:
            # Just exit if any error
            print("some error : " + str(e))
            break

print ("Downloaded {0} tweets, Saved to {1}".format(tweetCount, fName))
# Out:
# Downloading max 100000 tweets
# Downloaded 96 tweets
# Downloaded 196 tweets
# Downloaded 296 tweets
# Downloaded 396 tweets
# Downloaded 490 tweets
# Downloaded 590 tweets
# Downloaded 690 tweets
# Downloaded 790 tweets
# Downloaded 890 tweets
# Downloaded 990 tweets
# Downloaded 1090 tweets
# Downloaded 1190 tweets
# Downloaded 1290 tweets
# Downloaded 1390 tweets
# Downloaded 1490 tweets
# Downloaded 1590 tweets
# Downloaded 1690 tweets
# Downloaded 1790 tweets
# Downloaded 1890 tweets
# Downloaded 1990 tweets
# Downloaded 2087 tweets
# Downloaded 2187 tweets
# Downloaded 2287 tweets
# Downloaded 2387 tweets
# Downloaded 2487 tweets
# Downloaded 2587 tweets
# Downloaded 2687 tweets
# Downloaded 2787 tweets
# Downloaded 2887 tweets
# Downloaded 2987 tweets
# Downloaded 3087 tweets
# Downloaded 3187 tweets
# Downloaded 3287 tweets
# Downloaded 3387 tweets
# Downloaded 3487 tweets
# Downloaded 3587 tweets
# Downloaded 3687 tweets
# Downloaded 3787 tweets
# Downloaded 3887 tweets
# Downloaded 3987 tweets
# Downloaded 4087 tweets
# Downloaded 4187 tweets
# Downloaded 4287 tweets
# Downloaded 4387 tweets
# Downloaded 4487 tweets
# Downloaded 4587 tweets
# Downloaded 4687 tweets
# Downloaded 4787 tweets
# Downloaded 4887 tweets
# Downloaded 4987 tweets
# Downloaded 5087 tweets
# Downloaded 5187 tweets
# Downloaded 5287 tweets
# Downloaded 5387 tweets
# Downloaded 5487 tweets
# Downloaded 5587 tweets
# Downloaded 5687 tweets
# Downloaded 5787 tweets
# Downloaded 5887 tweets
# Downloaded 5987 tweets
# Downloaded 6087 tweets
# Downloaded 6187 tweets
# Downloaded 6287 tweets
# Downloaded 6387 tweets
# Downloaded 6487 tweets
# Downloaded 6587 tweets
# Downloaded 6687 tweets
# Downloaded 6787 tweets
# Downloaded 6887 tweets
# Downloaded 6987 tweets
# Downloaded 7087 tweets
# Downloaded 7187 tweets
# Downloaded 7287 tweets
# Downloaded 7387 tweets
# Downloaded 7487 tweets
# Downloaded 7587 tweets
# Downloaded 7687 tweets
# Downloaded 7787 tweets
# Downloaded 7887 tweets
# Downloaded 7987 tweets
# Downloaded 8087 tweets
# Downloaded 8187 tweets
# Downloaded 8287 tweets
# Downloaded 8387 tweets
# Downloaded 8487 tweets
# Downloaded 8587 tweets
# Downloaded 8687 tweets
# Downloaded 8787 tweets
# Downloaded 8887 tweets
# Downloaded 8987 tweets
# Downloaded 9087 tweets
# Downloaded 9187 tweets
# Downloaded 9287 tweets
# Downloaded 9387 tweets
# Downloaded 9487 tweets
# Downloaded 9587 tweets
# Downloaded 9687 tweets
# Downloaded 9787 tweets
# Downloaded 9887 tweets
# Downloaded 9987 tweets
# Downloaded 10087 tweets
# Downloaded 10187 tweets
# Downloaded 10287 tweets
# Downloaded 10387 tweets
# Downloaded 10487 tweets
# Downloaded 10587 tweets
# Downloaded 10687 tweets
# Downloaded 10787 tweets
# Downloaded 10887 tweets
# Downloaded 10987 tweets
# Downloaded 11087 tweets
# Downloaded 11187 tweets
# Downloaded 11287 tweets
# Downloaded 11387 tweets
# Downloaded 11487 tweets
# Downloaded 11587 tweets
# Downloaded 11687 tweets
# Downloaded 11787 tweets
# Downloaded 11887 tweets
# Downloaded 11987 tweets
# Downloaded 12087 tweets
# Downloaded 12187 tweets
# Downloaded 12287 tweets
# Downloaded 12387 tweets
# Downloaded 12487 tweets
# Downloaded 12587 tweets
# Downloaded 12687 tweets
# Downloaded 12787 tweets
# Downloaded 12887 tweets
# Downloaded 12987 tweets
# Downloaded 13087 tweets
# Downloaded 13187 tweets
# Downloaded 13287 tweets
# Downloaded 13387 tweets
# Downloaded 13487 tweets
# Downloaded 13587 tweets
# Downloaded 13687 tweets
# Downloaded 13787 tweets
# Downloaded 13887 tweets
# Downloaded 13987 tweets
# Downloaded 14087 tweets
# Downloaded 14187 tweets
# Downloaded 14287 tweets
# Downloaded 14387 tweets
# Downloaded 14487 tweets
# Downloaded 14587 tweets
# Downloaded 14687 tweets
# Downloaded 14787 tweets
